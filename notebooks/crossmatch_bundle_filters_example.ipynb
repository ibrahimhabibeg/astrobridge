# %%
# %load_ext autoreload
# %autoreload 2

# %%
from astrobridge.paper_pairing.core import CrossmatchBundle
from astrobridge.paper_pairing.filters import TitleKeywordFilter, ObjectNameInTitleOrAbstractFilter

# %%
bundle = CrossmatchBundle.load("../data/paper_crossmatch_bundles/mmu_desi_edr_sv3")
print(bundle.summary())
# Out:
# CrossmatchBundle Summary
# ========================================
#   hf_objects: 83030 rows, columns=['object_id', 'ra', 'dec']
#   simbad_objects: 82599 rows, columns=['main_id', 'coo_bibcode']
#   ads_papers: 10942 rows, columns=['bibcode', 'paper_title', 'abstract', 'doi', 'preprint_url']
#   relationships: 348778 rows, columns=['hf_id', 'simbad_main_id', 'bibcode']

# %%
filter = TitleKeywordFilter()
filtered_bundle = filter.apply(bundle)
print(filtered_bundle.summary())
# Out:
# CrossmatchBundle Summary
# ========================================
#   hf_objects: 23496 rows, columns=['object_id', 'ra', 'dec']
#   simbad_objects: 23081 rows, columns=['main_id', 'coo_bibcode']
#   ads_papers: 8584 rows, columns=['bibcode', 'paper_title', 'abstract', 'doi', 'preprint_url']
#   relationships: 93960 rows, columns=['hf_id', 'simbad_main_id', 'bibcode']

# %%
filter = ObjectNameInTitleOrAbstractFilter()
filtered_bundle = filter.apply(bundle)
print(filtered_bundle.summary())
# Out:
# CrossmatchBundle Summary
# ========================================
#   hf_objects: 20 rows, columns=['object_id', 'ra', 'dec']
#   simbad_objects: 15 rows, columns=['main_id', 'coo_bibcode']
#   ads_papers: 29 rows, columns=['bibcode', 'paper_title', 'abstract', 'doi', 'preprint_url']
#   relationships: 39 rows, columns=['hf_id', 'simbad_main_id', 'bibcode']
